# %% [markdown]
# ## CCWI/WDSA 2024 Battle of Water Networks Competition
# #### Water Demand Forcastng

# %%
import pandas as pd
import matplotlib as plt
import os

# improve matplotlib image quality
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
# load data
data_path  = data_path = '/home/bradw/workspace/water_demand_forecasting/data/' 
data = pd.read_excel(os.path.join(data_path, 'InflowData_1.xlsx'))
data = data.rename(columns={data.columns[0]: 'date_time'})
data.set_index('date_time', inplace=True)
data
# Out:
#                   DMA A (L/s)  DMA B (L/s)  DMA C (L/s)  DMA D (L/s)  \
# date_time
# 01/01/2021 00:00          NaN          NaN       3.7000          NaN
# 01/01/2021 01:00          NaN          NaN       3.5625          NaN
# 01/01/2021 02:00          NaN          NaN       3.2725          NaN
# 01/01/2021 03:00          NaN          NaN       2.8400          NaN
# 01/01/2021 04:00          NaN          NaN       2.7350          NaN
# ...                       ...          ...          ...          ...
# 24/07/2022 19:00      12.9175      17.7050      10.0100      38.7900
# 24/07/2022 20:00      12.8400      17.3500      10.0550      41.6675
# 24/07/2022 21:00      11.5575      14.8400       8.0775      42.8400
# 24/07/2022 22:00      10.4175      12.6925       6.1875      32.8325
# 24/07/2022 23:00      11.5250       9.8125       6.3825      25.7250
#
#                   DMA E (L/s)  DMA F (L/s)  DMA G (L/s)  DMA H (L/s)  \
# date_time
# ...

# %%
data.plot(kind='line', subplots=True, layout=(len(data.columns), 1), figsize=(12, 6 * len(data.columns)), legend=True)
# Out:
# array([[<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>],
#        [<Axes: xlabel='date_time'>]], dtype=object)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

data['DMA A (L/s)'].fillna(method='ffill', inplace=True)
# result = seasonal_decompose(data['DMA A (L/s)'], model='additive', period=30)
# Out:
# /tmp/ipykernel_13702/1849310221.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['DMA A (L/s)'].fillna(method='ffill', inplace=True)

# %%
data['DMA A (L/s)']
# Out:
# date_time
# 01/01/2021 00:00        NaN
# 01/01/2021 01:00        NaN
# 01/01/2021 02:00        NaN
# 01/01/2021 03:00        NaN
# 01/01/2021 04:00        NaN
#                      ...
# 24/07/2022 19:00    12.9175
# 24/07/2022 20:00    12.8400
# 24/07/2022 21:00    11.5575
# 24/07/2022 22:00    10.4175
# 24/07/2022 23:00    11.5250
# Name: DMA A (L/s), Length: 13679, dtype: float64
